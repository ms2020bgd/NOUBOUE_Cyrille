# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
url = "jupyter nbextensions_configurator enable --user"

# %%
req = requests.get(url)
soup = BeautifulSoup(req.text, "lxml")

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
<h1 id="0d02" class="gt gu dg bt bs di gv gw gx">Introducing SVT-AV1: a scalable open-source AV1 framework</h1>

# %%
item_title = soup.find('h1', attrs={"class":"gt gu dg bt bs di gv gw gx"})

# %%
item_title = soup.find_all('h1', attrs={"class":"gt gu dg bt bs di gv gw gx"})

# %%
item_title
# Out:
# [<h1 class="gt gu dg bt bs di gv gw gx" id="0d02">Introducing SVT-AV1: a scalable open-source AV1 framework</h1>,
#  <h1 class="gt gu dg bt bs di gv gw gx" id="b9b1">Evolving Regional Evacuation</h1>,
#  <h1 class="gt gu dg bt bs di gv gw gx" id="0642">Reimagining Experimentation Analysis at Netflix</h1>,
#  <h1 class="gt gu dg bt bs di gv gw gx" id="9023">Inca — Message Tracing and Loss Detection For Streaming Data @Netflix</h1>]

# %%
<h1 id="0642" class="gt gu dg bt bs di gv gw gx">Reimagining Experimentation Analysis at Netflix</h1>

# %%
soup = BeautifulSoup("")
